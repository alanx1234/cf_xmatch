# %%
import pandas as pd
df = pd.read_csv('cf_data/rotator_catalog.csv')
print(df['subgroup'].value_counts())
print(df['data_catalog'].value_counts())
# Out:
# subgroup
# Praesepe        868
# Pleiades        746
# M50             577
# M35             537
# NGC2516         535
# HPer            385
# M37             340
# M67             282
# NGC6811         269
# DSco            249
# APer            238
# NGC3532         225
# Collinder135    204
# IC2602          175
# NGC2547         173
# Hyades          154
# ROph_L1688      145
# NGC6819         132
# NGC2451A        129
# NGC6866         123
# SSco            121
# Antares         119
# NGC2281         116
# IC2391           96
# BSco             86
# M34              68
# NSco             64
# USco_fg          62
# NGC2548          59
# NGC1817          55
# RSco             45
# Ruprecht147      42
# NGC1750          39
# NGC1647          35
# NGC1758          21
# Taurus_C1        18
# Taurus_C5        16
# Taurus_C6        16
# Taurus_C7        12
# Taurus_D4        10
# NGC752            8
# Taurus_D2         8
# Taurus_D3         7
# Taurus_D1         4
# ...
